# %%
#Importing libraries
import pandas as pd
import numpy as np

# %%
#Loading the dataset
data = pd.read_csv('C:\\Users\\user\\Desktop\\Blackcoffer\\data.csv')

#Setting seed for reproducibility
np.random.seed(0)

# %%
#Looking at first 10 rows of the dataset
data.head(20)
# Out:
#     end_year  intensity               sector        topic  \
# 0        NaN        6.0               Energy          gas
# 1        NaN        6.0               Energy          oil
# 2        NaN        6.0               Energy  consumption
# 3        NaN        6.0          Environment          oil
# 4        NaN        6.0                  NaN       market
# 5        NaN        6.0               Energy          oil
# 6     2027.0       60.0           Government       market
# 7     2018.0       16.0               Energy          oil
# 8     2018.0       16.0                  NaN          gdp
# 9        NaN        6.0  Aerospace & defence          war
# 10       NaN        4.0        Manufacturing   production
# 11       NaN        6.0               Retail       export
# 12       NaN        6.0               Energy          oil
# 13       NaN        6.0               Energy          oil
# 14       NaN       12.0               Energy          oil
# ...

# %%
# Calculate the mode of start_year and median of end_year for the entire DataFrame
mode_of_start_year = data['start_year'].mode()[0]
median_of_end_year = data['end_year'].median()
mode_of_end_year = data['end_year'].mode()[0]
print(median_of_end_year)

# Replace the null values in start_year in the 'Energy' sector with the calculated mode
# Replace the null values in end_year in the 'Energy' sector with the calculated median
data.loc[data['start_year'].isnull(), 'start_year'] = mode_of_start_year
data.loc[(data['sector'] == 'Energy') & (data['end_year'].isnull()), 'end_year'] = median_of_end_year
# Out:
# 2020.0

# %%
#data.head(50)

# %%
total_cells = data.size
print('total cells:', total_cells)

#Getting the number of missing datapoints per column
missing_values_count = data.isnull().sum()

#Calculating total missing values
total_missing = missing_values_count.size
print('total missing values:',total_missing)

#Percentage of missing values
percent_missing = (total_missing/total_cells) * 100
print('Percentage of missing values:',percent_missing)
# Out:
# total cells: 17000
# total missing values: 17
# Percentage of missing values: 0.1

# %%
# Calculate the mean of end_year for 'Aerospace and defence' sector
aero_def_mean_end_year = data[data['sector'] == 'Aerospace & defence']['end_year'].mean()

# Replace the null end_year values in 'Aerospace and defence' sector with the calculated mean
data.loc[(data['sector'] == 'Aerospace & defence') & (data['end_year'].isnull()), 'end_year'] = int(round(aero_def_mean_end_year))

# %%
# Calculate the mean of end_year for 'Aerospace and defence' sect
construction_mean_end_year = data[data['sector'] == 'Construction']['end_year'].mean()

# Replace the null end_year values in 'Aerospace and defence' sector with the calculated mean
data.loc[(data['sector'] == 'Construction') & (data['end_year'].isnull()), 'end_year'] = int(round(aero_def_mean_end_year))

# %%
# Calculate the mean of end_year for 'Manufacturing' sector where end_year is not null
environ_mean_end_year = data[(data['sector'] == 'Environment') & (data['end_year'].notnull())]['end_year'].mean()

# Fill the null end_year values in 'Manufacturing' sector with the calculated mean
data.loc[(data['sector'] == 'Environment') & (data['end_year'].isnull()), 'end_year'] = int(round(environ_mean_end_year))

# %%
# Calculate the mean of end_year for 'Manufacturing' sector where end_year is not null
fin_mean_end_year = data[(data['sector'] == 'Financial services') & (data['end_year'].notnull())]['end_year'].mean()

# Fill the null end_year values in 'Manufacturing' sector with the calculated mean
data.loc[(data['sector'] == 'Financial services') & (data['end_year'].isnull()), 'end_year'] = int(round(fin_mean_end_year))

# %%
# Calculate the mean of end_year for 'Manufacturing' sector where end_year is not null
it_mean_end_year = data[(data['sector'] == 'Information Technology') & (data['end_year'].notnull())]['end_year'].mean()

# Fill the null end_year values in 'Manufacturing' sector with the calculated mean
data.loc[(data['sector'] == 'Information Technology') & (data['end_year'].isnull()), 'end_year'] = int(round(it_mean_end_year))

# %%
# Calculate the mean of end_year for 'Manufacturing' sector where end_year is not null
gov_mean_end_year = data[(data['sector'] == 'Government') & (data['end_year'].notnull())]['end_year'].mean()

# Fill the null end_year values in 'Manufacturing' sector with the calculated mean
data.loc[(data['sector'] == 'Government') & (data['end_year'].isnull()), 'end_year'] = int(round(gov_mean_end_year))

# %%
# Calculate the mean of end_year for 'Manufacturing' sector where end_year is not null
manufacturing_mean_end_year = data[(data['sector'] == 'Manufacturing') & (data['end_year'].notnull())]['end_year'].mean()

# Fill the null end_year values in 'Manufacturing' sector with the calculated mean
data.loc[(data['sector'] == 'Manufacturing') & (data['end_year'].isnull()), 'end_year'] = int(round(manufacturing_mean_end_year))

# %%
# Calculate the mean of end_year for 'Manufacturing' sector where end_year is not null
retail_mean_end_year = data[(data['sector'] == 'Retail') & (data['end_year'].notnull())]['end_year'].mean()

# Fill the null end_year values in 'Manufacturing' sector with the calculated mean
data.loc[(data['sector'] == 'Retail') & (data['end_year'].isnull()), 'end_year'] = int(round(retail_mean_end_year))

# %%
# Calculate the mean of end_year for 'Manufacturing' sector where end_year is not null
support_mean_end_year = data[(data['sector'] == 'Support services') & (data['end_year'].notnull())]['end_year'].mean()

# Fill the null end_year values in 'Manufacturing' sector with the calculated mean
data.loc[(data['sector'] == 'Support services') & (data['end_year'].isnull()), 'end_year'] = int(round(support_mean_end_year))

# %%
# Calculate the mean of end_year for 'Manufacturing' sector where end_year is not null
transport_mean_end_year = data[(data['sector'] == 'Transport') & (data['end_year'].notnull())]['end_year'].mean()

# Fill the null end_year values in 'Manufacturing' sector with the calculated mean
data.loc[(data['sector'] == 'Transport') & (data['end_year'].isnull()), 'end_year'] = int(round(transport_mean_end_year))

# %%
data.isnull().sum()
# Out:
# end_year      179
# intensity      38
# sector        229
# topic          93
# insight         0
# url             0
# region        453
# start_year      0
# impact        966
# added           0
# published      74
# country       650
# relevance       1
# pestle         93
# source          1
# title           0
# likelihood     38
# dtype: int64

# %%
# Replacing all NA's with the value that comes directly after it in the same column
#data.fillna(method = 'bfill', limit = None, inplace = True)
data.fillna(method = 'ffill', limit = None, inplace = True)

# %%
data.isnull().sum()
# Out:
# end_year      0
# intensity     0
# sector        0
# topic         0
# insight       0
# url           0
# region        0
# start_year    0
# impact        0
# added         0
# published     0
# country       0
# relevance     0
# pestle        0
# source        0
# title         0
# likelihood    0
# dtype: int64

# %%
# Save the updated DataFrame to a CSV file
output_csv_path = 'C:\\ProgramData\\MySQL\\MySQL Server 8.0\\Uploads\\updated_data.csv'
data.to_csv(output_csv_path, index=False)
